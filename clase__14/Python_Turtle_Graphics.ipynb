# %% [markdown]
# <a href="https://colab.research.google.com/github/Juarodriguezperez/PC_Python_2025II/blob/main/clase__14/Python_Turtle_Graphics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso de Programación de Computadores en Python
# ## 🐢 **Introducción a Turtle Graphics en Python**
# #### Universidad Nacional de Colombia
# ---

# %% [markdown]
# ### 🔧 Cómo usar este notebook
#
# - Ejecuta las celdas de código con `Shift+Enter`.
# - Cada sección contiene explicación, ejemplos ejecutables y ejercicios.
#
# ¡Manos a la obra! 🚀

# %% [markdown]
# ## 🎯 Objetivos de aprendizaje
# - Comprender qué es **Turtle Graphics** y cómo funciona en Python.
# - Aprender a **dibujar líneas, formas y figuras básicas**.
# - Aplicar **colores y rellenos** en dibujos.
# - Usar **funciones de Turtle** para crear proyectos creativos.
# - Desarrollar lógica de programación visual mediante movimientos y bucles.

# %% [markdown]
# # ⚙️ **Configuración para usar Turtle en Colab**
#
# La biblioteca estándar `turtle` no funciona directamente en Colab dado que necesita una **ventana gráfica local**.
# Sin embargo, es posible usar una versión adaptada llamada **`ColabTurtlePlus`**, que muestra el dibujo directamente en el notebook.
#
# Ejecuta la siguiente celda **una sola vez al inicio** para instalarla y configurarla.

# %%
#Instalación de ColabTurtlePlus (solo una vez por sesión)
# !pip install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
initializeTurtle()
# Out:
# ...
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#
#       </svg>

# %% [markdown]
# ## 💻 **Ejecución local (opcional)**
#
# Si deseas ejecutar los programas **fuera de Colab**, puedes usar la biblioteca estándar `turtle`, que viene incluida con Python.
#
# ### Pasos:
# 1. Abre tu editor de Python local.
# 2. Crea un nuevo archivo, por ejemplo `tortuga.py`.
# 3. Escribe el siguiente código de prueba para crear una tortuga y moverla:
# ```python
#    import turtle   # Se importa el módulo estándar
#
#    t = turtle.Turtle()   # Se crea un objeto tortuga
#    t.forward(100)        # Avanza 100 unidades
#    t.right(90)           # Gira 90 grados a la derecha
#    t.forward(100)        # Avanza nuevamente
#    turtle.done()         # Finaliza el dibujo y mantiene la ventana abierta
# ```
# 4. Abre una terminal en la carpeta del archivo (o directamente con **Run**) y ejecuta:
# ```python
#    python tortuga.py
# ```
# 5. Se abrirá una ventana gráfica mostrando el dibujo en tiempo real. 🎨
#
# 💡 `ColabTurtlePlus`, que tiene los mismos comandos que `turtle`, por lo que todo lo que aprendas aquí también funcionará fuera del entorno.

# %% [markdown]
# # 1️⃣ **¿Qué es Turtle Graphics?**
#
# **Turtle Graphics** es un módulo de Python que permite crear **dibujos y gráficos** mediante el movimiento de una “tortuga virtual” que deja un trazo mientras se desplaza.
# ### 🧩 **Imagina**:
# - Una tortuga camina sobre una hoja.
# - Cada vez que se mueve, **dibuja una línea**.
# - Puedes decirle que avance, gire, cambie de color, o levante el lápiz.
# - Es ideal para iniciar con la **programación visual** y la **lógica secuencial**.

# %% [markdown]
# # 2️⃣ **Dibujando líneas y movimientos básicos**
#
# Con Turtle podemos controlar el **movimiento**, el **trazo** y la **apariencia** de la tortuga.
# Cada dibujo se crea a partir de tres acciones principales:
#
# 1. **Moverse** (`forward()`, `backward()`)
# 2. **Girar** (`right()`, `left()`)
# 3. **Controlar el lápiz** (`penup()`, `pendown()`)
#
# ### 🧭 **Direcciones y movimientos**
#
# - Por defecto, la tortuga inicia apuntando hacia la **derecha (0°)**.
# - `right(90)` la gira **90° a la derecha**.
# - `left(90)` la gira **90° a la izquierda**.
# - Puedes moverla hacia atrás con `backward(x)`.
#
# ### 🖊️ **Control del lápiz**
#
# - `penup()` → levanta el lápiz (no dibuja).
# - `pendown()` → baja el lápiz (vuelve a dibujar).
# - `goto(x, y)` → mueve la tortuga a coordenadas específicas.
#
# ### 🎨 **Personalización de la tortuga y el trazo**
#
# Puedes personalizar la apariencia de la tortuga y el estilo del dibujo con los siguientes comandos:
#
# | Comando | Descripción |
# |:---------|:-------------|
# | `color("color")` | Cambia el color del trazo (por nombre o código RGB). |
# | `pencolor("color")` | Cambia el color del lápiz (igual que `color()`). |
# | `fillcolor("color")` | Cambia el color de relleno para figuras cerradas. |
# | `pensize(x)` | Ajusta el grosor de la línea. |
# | `shape("nombre")` | Cambia la forma de la tortuga (`"turtle"`, `"arrow"`, `"circle"`, etc.). |
# | `speed(n)` | Controla la velocidad de movimiento (1–10 o `"fastest"`). |

# %%
#Ejemplo: movimientos y personalización
from ColabTurtlePlus.Turtle import *

initializeTurtle()
color("purple")
pensize(4)
shape("turtle")
speed(6)

# Dibujo en forma de "L"
forward(100)
right(90)
forward(60)

# Mover sin dibujar
penup()
goto(-50, 50)
pendown()

color("orange")
# Dibujar un triángulo simple
for _ in range(3):
    forward(80)
    left(120)

# Volver al centro y mostrar texto
penup()
goto(0, 0)
pendown()
color("red")

for i in range(36):
    forward(100)
    right(100)

for i in range(36):
    for j in range(4):
        forward(100)
        right(90)
    right(10)
penup()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# ## 🌀 **Bucles anidados y patrones decorativos**
#
# Hasta ahora usamos un **solo bucle `for`** para dibujar figuras regulares (cuadrados, triángulos, etc.).
# Pero podemos usar **bucles anidados** para crear **patrones más elaborados o repetitivos**.
#
# ### 📘 **Diferencia entre tipos de bucle**
#
# | Tipo | Descripción | Ejemplo |
# |------|--------------|---------|
# | **Simple** | Repite un mismo movimiento en una figura. | Dibuja un cuadrado. |
# | **Anidado** | Un bucle externo repite una figura completa varias veces, rotándola o cambiando color. | Dibuja varios cuadrados girados entre sí. |
#
# ###💡 **Ejemplo: bucle simple (no anidado)**
#
# Este código usa un solo bucle, pero el ángulo de giro hace que el trazo forme un patrón similar a una flor.
#
# ```python
# for i in range(36):
#     forward(100)
#     right(100)
# ```
# ### 💫 **Ejemplo: bucle anidado**
#
# El primer `for` dibuja un cuadrado, y el segundo repite el cuadrado varias veces, girándolo un poco cada vez.
#
# ```python
# for i in range(36):
#     for j in range(4):
#         forward(100)
#         right(90)
#     right(10)
# ```
#
# 💡 Esto produce un patrón circular de cuadrados superpuestos — un efecto de flor o mandala.

# %% [markdown]
# # 3️⃣ **Formas geométricas y bucles**
#
# Cuando necesitamos dibujar **figuras con lados iguales** (como triángulos, cuadrados o hexágonos),
# usar un bucle `for` hace el código más corto y legible.
#
# Cada figura se puede pensar como:
# - Repetir **un mismo movimiento** (`forward()`)
# - Y luego **un mismo giro** (`right()` o `left()`)
#
# ### 🧩 **Ejemplo: cuadrado**
#
# Un cuadrado tiene 4 lados de igual longitud y giros de **90°**.
#
# ```python
# for _ in range(4):
#     forward(100)
#     right(90)
# ```
# ### 🧩 **Ejemplo: triángulo equilátero**
#
# Un triángulo equilátero tiene 3 lados y giros de 120°.
# ```python
# for _ in range(3):
#     forward(100)
#     left(120)
# ```
# ## 🛞 **Generalización**
#
# Si una figura tiene **n lados**, cada giro será de **360 / n grados**. Esto nos permite crear un bucle para **cualquier polígono regular**.
#
# ```python
# for _ in range(lados):
#     forward(longitud)
#     right(360 / lados)
# ```

# %% [markdown]
# ##🧪 **Reto rápido (formas básicas)**

# %%
#@title **Instrucciones:**
#@markdown Observa el código y escribe tu **predicción** antes de ejecutarlo.
#@markdown
#@markdown ```python
#@markdown from ColabTurtlePlus.Turtle import *
#@markdown initializeTurtle()
#@markdown color("green")
#@markdown pensize(3)
#@markdown for i in range(6):
#@markdown     forward(100)
#@markdown     right(60)
#@markdown ```
Prediccion = "hexágono verde de lado 100 y giros de 60°"  #@param {type:"string"}

from ColabTurtlePlus.Turtle import *
initializeTurtle()
color("green")
pensize(3)

for i in range(6):
    forward(100)
    right(60)

print("\nTu predicción:")
print(Prediccion if Prediccion.strip() else "(sin respuesta)")
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="500.0" y2="300.0" stroke-linecap="round" style="stroke:green;stroke-width:3" /><line x1="500.0" y1="300.0" x2="550.0" y2="386.603" stroke-linecap="round" style="stroke:green;stroke-width:3" /><line x1="550.0" y1="386.603" x2="500.0" y2="473.206" stroke-linecap="round" style="stroke:green;stroke-width:3" /><line x1="500.0" y1="473.206" x2="400.0" y2="473.206" stroke-linecap="round" style="stroke:green;stroke-width:3" /><line x1="400.0" y1="473.206" x2="350.0" y2="386.603" stroke-linecap="round" style="stroke:green;stroke-width:3" /><line x1="350.0" y1="386.603" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:green;stroke-width:3" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(390,400.0,300.0) translate(400.0, 300.0)">
# ...

# %% [markdown]
# ## 🎨 **¿Solo figuras geométricas? ¡No necesariamente!**
#
# Aunque muchas figuras en Turtle se basan en **polígonos regulares**, también puedes crear formas **no estrictamente geométricas**.
#
# Basta con **cambiar los ángulos o longitudes** dentro del bucle para obtener diseños más creativos.
#
# ###💡 **Ejemplo: estrella**
#
# En este caso, los giros no son los de un polígono regular (no suman 360°),
# pero al repetirse 5 veces producen un trazado cerrado y simétrico.
#
# ```python
# for i in range(5):
#     forward(100)
#     right(144)
# ```

# %% [markdown]
# ## 🌀 **Bucles anidados y patrones decorativos**
#
# Hasta ahora usamos un **solo bucle `for`** para dibujar figuras regulares (cuadrados, triángulos, etc.).
# Pero podemos usar **bucles anidados** para crear **patrones más elaborados o repetitivos**.
#
# ### 📘 **Diferencia entre tipos de bucle**
#
# | Tipo | Descripción | Ejemplo |
# |------|--------------|---------|
# | **Simple** | Repite un mismo movimiento en una figura. | Dibuja un cuadrado. |
# | **Anidado** | Un bucle externo repite una figura completa varias veces, rotándola o cambiando color. | Dibuja varios cuadrados girados entre sí. |
#
# ###💡 **Ejemplo: bucle simple (no anidado)**
#
# Este código usa un solo bucle, pero el ángulo de giro hace que el trazo forme un patrón similar a una flor.
#
# ```python
# for i in range(36):
#     forward(100)
#     right(100)
# ```
# ### 💫 **Ejemplo: bucle anidado**
#
# El primer `for` dibuja un cuadrado, y el segundo repite el cuadrado varias veces, girándolo un poco cada vez.
#
# ```python
# for i in range(36):
#     for j in range(4):
#         forward(100)
#         right(90)
#     right(10)
# ```
#
# 💡 Esto produce un patrón circular de cuadrados superpuestos — un efecto de flor o mandala.

# %%
#Demostración: bucle anidado (patrón decorativo)
from ColabTurtlePlus.Turtle import *

initializeTurtle()
shape("turtle")
speed(10)
color("purple")

# Bucle anidado: dibuja cuadrados girados
for i in range(36):
    for j in range(4):
        forward(80)
        right(90)
    right(10)

penup()
goto(-80, -160)
pendown()
color("red")
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# # 6️⃣ **Colores y relleno de figuras**
#
# Además de trazar líneas, Turtle permite **agregar color y relleno** a las figuras.  Esto ayuda a que los dibujos sean más **visuales y creativos**
#
# ## 🎨 **Comandos principales**
#
# | Comando | Descripción |
# |:---------|:-------------|
# | `color("color")` | Cambia el color del trazo (puedes usar nombres o valores RGB). |
# | `fillcolor("color")` | Define el color que se usará para rellenar una figura cerrada. |
# | `begin_fill()` | Indica el inicio del área a rellenar. |
# | `end_fill()` | Cierra el área y aplica el relleno con el color seleccionado. |
#
# ### 🧩 **Ejemplo: cuadrado relleno**
#
# 1. Se define un color de línea con `color()`.
# 2. Se define el color del relleno con `fillcolor()`.
# 3. Se encierra el dibujo entre `begin_fill()` y `end_fill()`.
#
# ```python
# color("black")
# fillcolor("yellow")
# begin_fill()
# for i in range(4):
#     forward(100)
#     right(90)
# end_fill()
# ```

# %%
#Ejemplo: colores y relleno de figuras
from ColabTurtlePlus.Turtle import *

initializeTurtle()
speed(8)
shape("turtle")

# Cuadrado relleno
color("black")
fillcolor("gold")
begin_fill()
for _ in range(4):
    forward(100)
    right(90)
end_fill()

# Mover a otro lugar y dibujar un triángulo relleno
penup()
goto(-150, 0)
pendown()

color("darkgreen")
fillcolor("lightgreen")
begin_fill()
for _ in range(3):
    forward(100)
    left(120)
end_fill()

# Dibujar un círculo
penup()
goto(150, 0)
pendown()

color("purple")
fillcolor("violet")
begin_fill()
circle(50)
end_fill()

penup()
goto(-60, -140)
pendown()
color("red")
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 500.0 300.0  L 500.0 400.0  L 400.0 400.0  L 400.0 300.0 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="gold" /><path fill-rule="evenodd" fill-opacity="1" d="M 250.0 300.0  L 350.0 300.0  L 300.0 213.397  L 250.0 300.0 " stroke-linecap="round" style="stroke:darkgreen;stroke-width:1" fill="lightgreen" /><path fill-rule="evenodd" fill-opacity="1" d="M 550.0 300.0  A 50 50 0 0 0 550.0 200.0  A 50 50 0 0 0 550.0 300.0 " stroke-linecap="round" style="stroke:purple;stroke-width:1" fill="violet" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90.0,340.0,440.0) translate(340.0, 440.0)">
# ...

# %% [markdown]
# # 7️⃣ **Uso de funciones Turtle en proyectos creativos**
#
# Hasta ahora, hemos dibujado cada figura paso a paso.
# Pero en proyectos más grandes o dibujos con muchos elementos,  es mejor **usar funciones** para organizar el código y reutilizarlo fácilmente.
#
# ## 🧩 **Ventajas de usar funciones**
#
# - Permiten **reutilizar** el mismo dibujo varias veces.
# - Hacen el código más **limpio y modular**.
# - Permiten combinar figuras pequeñas para crear **escenas completas**.
#
# ###📘 **Ejemplo: función para un cuadrado**
#
# ```python
# def cuadrado(lado, color_linea, color_relleno):
#     color(color_linea)
#     fillcolor(color_relleno)
#     begin_fill()
#     for _ in range(4):
#         forward(lado)
#         right(90)
#     end_fill()
# ```
# Luego puedes usarla varias veces:
#
# ```python
# cuadrado(80, "black", "yellow")
# penup()
# goto(100, 100)
# pendown()
# cuadrado(50, "red", "orange")
# ```
# ### 🎨 **Composición creativa**
#
# Combinando funciones simples se pueden construir dibujos más elaborados,
# como flores, casas, banderas o patrones decorativos.

# %%
#Ejemplo: uso de funciones para componer dibujos
from ColabTurtlePlus.Turtle import *

initializeTurtle()
speed(8)
shape("turtle")

# Definición de funciones
def cuadrado(lado, color_linea, color_relleno):
    color(color_linea)
    fillcolor(color_relleno)
    begin_fill()
    for _ in range(4):
        forward(lado)
        right(90)
    end_fill()

def triángulo(lado, color_linea, color_relleno):
    color(color_linea)
    fillcolor(color_relleno)
    begin_fill()
    for _ in range(3):
        forward(lado)
        left(120)
    end_fill()

def casa():
    cuadrado(100, "brown", "peru")
    triángulo(100, "black", "darkred")

# Dibujo compuesto
penup()
goto(-50, -50)
pendown()
casa()

penup()
goto(150, -50)
pendown()
casa()

penup()
goto(-60, -160)
pendown()
color("blue")
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 350.0 350.0  L 450.0 350.0  L 450.0 450.0  L 350.0 450.0  L 350.0 350.0 " stroke-linecap="round" style="stroke:brown;stroke-width:1" fill="peru" /><path fill-rule="evenodd" fill-opacity="1" d="M 350.0 350.0  L 450.0 350.0  L 400.0 263.397  L 350.0 350.0 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="darkred" /><path fill-rule="evenodd" fill-opacity="1" d="M 550.0 350.0  L 650.0 350.0  L 650.0 450.0  L 550.0 450.0  L 550.0 350.0 " stroke-linecap="round" style="stroke:brown;stroke-width:1" fill="peru" /><path fill-rule="evenodd" fill-opacity="1" d="M 550.0 350.0  L 650.0 350.0  L 600.0 263.397  L 550.0 350.0 " stroke-linecap="round" style="stroke:black;stroke-width:1" fill="darkred" />
#
#
# ...

# %% [markdown]
# ## 🧪 **Reto rápido (proyecto creativo con múltiples elementos)**

# %%
#@title **Instrucciones:**
#@markdown Observa el siguiente código y **predice qué dibujo formará** antes de ejecutarlo.

#@markdown Piensa: ¿Qué figura dibuja cada función? y ¿Qué efecto se crea al combinar colores y repeticiones?
#@markdown
#@markdown ```python
#@markdown from ColabTurtlePlus.Turtle import *
#@markdown initializeTurtle()
#@markdown speed(8)
#@markdown
#@markdown def trazo_vertical():
#@markdown     color("forestgreen")
#@markdown     pensize(4)
#@markdown     right(90)
#@markdown     forward(60)
#@markdown     left(90)
#@markdown
#@markdown def figura_central(tono):
#@markdown     color(tono)
#@markdown     for i in range(6):
#@markdown         circle(20, 60)
#@markdown         left(120)
#@markdown
#@markdown def franja_inferior():
#@markdown     color("limegreen")
#@markdown     pensize(6)
#@markdown     penup()
#@markdown     goto(-200, -100)
#@markdown     pendown()
#@markdown     forward(400)
#@markdown
#@markdown franja_inferior()
#@markdown
#@markdown penup(); goto(-100, -40); pendown()
#@markdown trazo_vertical(); figura_central("deeppink")
#@markdown
#@markdown penup(); goto(0, -40); pendown()
#@markdown trazo_vertical(); figura_central("gold")
#@markdown
#@markdown penup(); goto(100, -40); pendown()
#@markdown trazo_vertical(); figura_central("orange")
#@markdown ```
Prediccion = "flor amarilla, flor rosada y flor naranja"  #@param {type:"string"}

from ColabTurtlePlus.Turtle import *

initializeTurtle()
speed(8)

def franja_inferior():
    color("limegreen"); pensize(6)
    penup(); goto(-220, -100); pendown()
    forward(440)

def trazo_vertical(altura=60):
    color("forestgreen"); pensize(4)
    setheading(90)
    pendown()
    forward(altura)

def figura_central(tono, figures=6, radio=20, ang=60):
    pencolor(tono); color(tono); pensize(2)
    x, y = position()
    for k in range(figures):
        setheading(90 + k * (360 / figures))
        penup(); goto(x, y); pendown()
        circle(radio, ang)
        left(180 - ang)
        circle(radio, ang)

# Escena
franja_inferior()

# Flor 1
penup(); goto(-120, -100); pendown()
trazo_vertical(70); figura_central("deeppink")

# Flor 2
penup(); goto(0, -100); pendown()
trazo_vertical(70); figura_central("gold")

# Flor 3
penup(); goto(120, -100); pendown()
trazo_vertical(70); figura_central("orange")

print("\nTu predicción:")
print(Prediccion if Prediccion.strip() else "(sin respuesta)")
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="180.0" y1="400.0" x2="620.0" y2="400.0" stroke-linecap="round" style="stroke:limegreen;stroke-width:6" /><line x1="280.0" y1="400.0" x2="280.0" y2="330.0" stroke-linecap="round" style="stroke:forestgreen;stroke-width:4" /><path d="M 280.0 330.0 A 20 20 0 0 0 270.0 312.679" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:deeppink;stroke-width:2"/><path d="M 270.0 312.679 A 20 20 0 0 0 280.0 330.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:deeppink;stroke-width:2"/><path d="M 280.0 330.0 A 20 20 0 0 0 260.0 330.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:deeppink;stroke-width:2"/><path d="M 260.0 330.0 A 20 20 0 0 0 280.0 330.0" stroke-linecap="round"
# ...

# %% [markdown]
# # 💡 **Tips y recomendaciones**
#
# ### 🧭 **Uso general**
# - Antes de cada nuevo dibujo, usa `initializeTurtle()` para **reiniciar el lienzo**.
# - Ajusta la velocidad con `speed(n)` (1–10) para observar el movimiento o hacerlo más rápido.
# - Si la tortuga se desorienta, usa `setheading(0)` para restablecerla apuntando a la derecha.
# - Combina `penup()`, `pendown()` y `goto(x, y)` para moverte sin dejar trazos.
# - Si el dibujo se sale del lienzo, prueba con `reset()` o redimensiona el área de dibujo (`initializeTurtle(canvas_width=600, canvas_height=400)`).
#
# ### 🎨 **Creatividad**
# - Experimenta con **colores y tamaños**: usa `color()`, `fillcolor()`, `pensize()`, y distintas formas (`shape("turtle")`, `"arrow"`, `"circle"`…).
# - Crea tus propias **funciones** para agrupar trazos y combinarlas en proyectos artísticos (flores, casas, estrellas, mandalas).
# - No te limites a figuras regulares: juega con **ángulos “imperfectos”** o mezclas de curvas (`circle(r, grados)`) para diseños más orgánicos.
# - Usa bucles `for` para patrones repetitivos y **bucles anidados** para composiciones decorativas.

# %% [markdown]
# # 📚 **Recursos recomendados**
#
# - 📘 **Documentación oficial de Turtle:**
#   🔗 [https://docs.python.org/3/library/turtle.html](https://docs.python.org/3/library/turtle.html)
# - 🧩 **ColabTurtlePlus:**
#   🔗 [https://pypi.org/project/ColabTurtlePlus/](https://pypi.org/project/ColabTurtlePlus/)
# - 🎨 **Colores en Python:**
#   🔗 [Lista de nombres de colores CSS](https://www.w3schools.com/colors/colors_names.asp)
#   (Puedes usar estos mismos nombres en `color("nombre")`)

# %% [markdown]
# ---
#
# # 🧮 **Ejercicios**

# %% [markdown]
# a) Dibuja una **figura geométrica de 5 lados** usando un bucle `for`. Elige color, grosor y velocidad a tu gusto.

# %%
"""
Aquí debajo escribe tu solución
"""
from ColabTurtlePlus.Turtle import *
initializeTurtle()
speed(8)
pensize(4)
pencolor("cyan")

for _ in range(5):
  forward(100)
  right(360 / 5)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="500.0" y2="300.0" stroke-linecap="round" style="stroke:cyan;stroke-width:4" /><line x1="500.0" y1="300.0" x2="530.902" y2="395.106" stroke-linecap="round" style="stroke:cyan;stroke-width:4" /><line x1="530.902" y1="395.106" x2="450.0" y2="453.885" stroke-linecap="round" style="stroke:cyan;stroke-width:4" /><line x1="450.0" y1="453.885" x2="369.098" y2="395.106" stroke-linecap="round" style="stroke:cyan;stroke-width:4" /><line x1="369.098" y1="395.106" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:cyan;stroke-width:4" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(378.0,400.0,300.0) translate(400.0, 300.0)">
# ...

# %% [markdown]
# b) Crea una función que dibuje un **cuadrado relleno de color**. Luego, usa esa función para dibujar tres cuadrados de diferentes tamaños y colores en distintas posiciones.

# %%
"""
Aquí debajo escribe tu solución
"""
from ColabTurtlePlus.Turtle import *
initializeTurtle()
speed(8)
pensize(4)
def cuadrado(lado, color_linea, color_relleno):
  color(color_linea)
  fillcolor(color_relleno)
  begin_fill()
  for _ in range(4):
        forward(lado)
        right(90)
  end_fill()

cuadrado(100, "red", "red")
penup()
goto(80,20)
pendown()
cuadrado(50, "green", "green")
penup()
goto(-100,100)
pendown()
cuadrado(150, "purple", "purple")
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 500.0 300.0  L 500.0 400.0  L 400.0 400.0  L 400.0 300.0 " stroke-linecap="round" style="stroke:red;stroke-width:4" fill="red" /><path fill-rule="evenodd" fill-opacity="1" d="M 480.0 280.0  L 530.0 280.0  L 530.0 330.0  L 480.0 330.0  L 480.0 280.0 " stroke-linecap="round" style="stroke:green;stroke-width:4" fill="green" /><path fill-rule="evenodd" fill-opacity="1" d="M 300.0 200.0  L 450.0 200.0  L 450.0 350.0  L 300.0 350.0  L 300.0 200.0 " stroke-linecap="round" style="stroke:purple;stroke-width:4" fill="purple" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90,300.0,200.0) translate(300.0, 200.0)">
# ...

# %% [markdown]
# c) Diseña una función que reciba como parámetros el **número de lados** y el **color**, y dibuje el polígono correspondiente. Pruébala con distintos valores.

# %%
"""
Aquí debajo escribe tu solución
"""
from ColabTurtlePlus.Turtle import *
initializeTurtle()
speed(8)
pensize(4)
pencolor("gold")

var1 = 0
var2 = 1
for _ in range(20):
  circle(var2 / 2,90)
  temp = var1
  var1 = var2
  var2 = temp + var1

penup()
goto(0,0)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 0.5 0.5 0 0 0 400.5 299.5" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:gold;stroke-width:4"/><path d="M 400.5 299.5 A 0.5 0.5 0 0 0 400.0 299.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:gold;stroke-width:4"/><path d="M 400.0 299.0 A 1.0 1.0 0 0 0 399.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:gold;stroke-width:4"/><path d="M 399.0 300.0 A 1.5 1.5 0 0 0 400.5 301.5" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:gold;stroke-width:4"/><path d="M 400.5 301.5 A 2.5 2.5 0 0 0 403.0 299.0" stroke-linecap="round"
# ...

# %% [markdown]
# d) Crea un dibujo libre combinando **formas geométricas** y **rellenos de color**. Puedes crear una **bandera, una flor o una figura artística** usando funciones personalizadas.

# %%
"""
Aquí debajo escribe tu solución
"""
# Out:
# '\nAquí debajo escribe tu solución\n'
